# %% [markdown]
# <a href="https://colab.research.google.com/github/Sauvi72/Data_sci_Python/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

n = int(input("Number of items: "))

prices = []

for i in range(n):
    prices.append(int(input()))

prices = np.array(prices)

print("Prices =", prices)

print("Total Bill    =", np.sum(prices))
print("Average Price =", np.mean(prices))
print("Minimum Price =", np.min(prices))
print("Maximum Price =", np.max(prices))
print("Std Dev       =", np.std(prices))

print("Sorted Prices =", np.sort(prices))
print("Unique Prices =", np.unique(prices))

print("Items > 100   =", prices[np.where(prices > 100)])
# Out:
# Number of items: 4
# 3
# 6
# 7
# 8
# Prices = [3 6 7 8]
# Total Bill    = 24
# Average Price = 6.0
# Minimum Price = 3
# Maximum Price = 8
# Std Dev       = 1.8708286933869707
# Sorted Prices = [3 6 7 8]
# Unique Prices = [3 6 7 8]
# Items > 100   = []
